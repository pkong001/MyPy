# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#                                               0.0/205.5 MB ? eta -:--:--
#                                              0.8/205.5 MB 25.4 MB/s eta 0:00:09
#                                              1.7/205.5 MB 21.5 MB/s eta 0:00:10
#                                              2.7/205.5 MB 21.3 MB/s eta 0:00:10
#                                              3.7/205.5 MB 21.7 MB/s eta 0:00:10
#                                              4.7/205.5 MB 21.5 MB/s eta 0:00:10
#      -                                       5.8/205.5 MB 21.6 MB/s eta 0:00:10
#      -                                       7.0/205.5 MB 23.4 MB/s eta 0:00:09
#      -                                       8.5/205.5 MB 24.7 MB/s eta 0:00:08
#      -                                      10.2/205.5 MB 25.1 MB/s eta 0:00:08
#      --                                     12.0/205.5 MB 28.5 MB/s eta 0:00:07
# ...

# %%
python.ext --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python.ext --version
#
# NameError: name 'python' is not defined
